# %%
import eikon as ek
import pandas as pd
import numpy as np
ek.set_app_key('f01a5002bf4649578cf705c13f7d30d9bdcf2c9d')

# %% [markdown]
# USETNP=ECI

# %%
codes = ['DSPLY_NME2', 'CF_TIME', 'CF_DATE', 'ECON_ACT', 'ECON_PRIOR', 'RELEVANCE',
        'UNIT_PREFX', 'RTR_POLL', 'FCAST_HIGH', 'FCAST_LOW', 'FCAST_SEST']

# %%
columns = ['Instrument', 'Name', 'Time', 'Date', 'Actual', 'Prior', 'Relevance', 'Units', 'Poll', 'Poll (High)', 'Poll (Low)', 'Smart Est.']

# %%
indicators = ['USCPI=ECI', 'USCPI=ECI', 'USJOB=ECI','USRSL=ECI', 'USIP=ECI',
'USUMSP=ECI', 'USHST=ECI', 'USPFDB=ECI', 'USPMCF=ECI', 'USMPMP=ECI','USMPSP=ECI',
'USEHS=ECI', 'USCONC=ECI', 'USHNS=ECI', 'USDGN=ECI', 'USGDPP=ECI', 'USGPCS=ECI',
'USUMSF=ECI', 'USPMI=ECI', 'USMPMF=ECI', 'USPMIP=ECI','USMPSF=ECI',
'USNPMI=ECI', 'USFORD=ECI', 'USNFAR=ECI', 'USUNR=ECI', 'USAVHE=ECI', 'USTBAL=ECI']

# %%
data, err = ek.get_data(indicators, fields = codes)

# %%
data.columns = columns

# %%
data
# Out:
#     Instrument                       Name      Time        Date  Actual  \
# 0    USCPI=ECI                 CPI MM, SA  13:30:00  2020-02-10     NaN
# 1    USCPI=ECI                 CPI MM, SA  13:30:00  2020-02-10     NaN
# 2    USJOB=ECI     Initial Jobless Claims  13:30:00  2020-02-10     NaN
# 3    USRSL=ECI            Retail Sales MM  13:30:00  2020-02-10     NaN
# 4     USIP=ECI   Industrial Production MM  14:15:00  2020-02-10     NaN
# 5   USUMSP=ECI    U Mich Sentiment Prelim  15:00:00  2020-02-10     NaN
# 6    USHST=ECI      Housing Starts Number  13:30:00  2020-02-10     NaN
# 7   USPFDB=ECI  Philly Fed Business Indx*  13:30:00  2020-02-10     NaN
# 8   USPMCF=ECI      Markit Comp Flash PMI  14:45:00  2020-02-21     NaN
# 9   USMPMP=ECI       Markit Mfg PMI Flash  14:45:00  2020-02-21     NaN
# 10  USMPSP=ECI      Markit Svcs PMI Flash  14:45:00  2020-02-21     NaN
# 11   USEHS=ECI        Existing Home Sales  15:00:00  2020-02-10     NaN
# ...
