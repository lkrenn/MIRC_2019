# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
import numpy as np
from fredapi import Fred as fred
fred = fred(api_key='bb925d9445b701c16c7e98390eedce44')

# %%
fred.search('wage growth').sort_values('popularity', ascending = False)
# Out:
#                                 frequency frequency_short               id  \
# series id
# CPIAUCSL                          Monthly               M         CPIAUCSL
# FEDFUNDS                          Monthly               M         FEDFUNDS
# PRS30006022                     Quarterly               Q      PRS30006022
# LCEAMN01USA657S                    Annual               A  LCEAMN01USA657S
# PRS84006021                     Quarterly               Q      PRS84006021
# DFF                          Daily, 7-Day               D              DFF
# PRS85006031                     Quarterly               Q      PRS85006031
# PRS85006062                     Quarterly               Q      PRS85006062
# LCEAMN01USQ659S                 Quarterly               Q  LCEAMN01USQ659S
# PRS85006021                     Quarterly               Q      PRS85006021
# FF               Weekly, Ending Wednesday               W               FF
# ...
